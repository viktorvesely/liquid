# %%
from pathlib import Path


s_liquid = "Liquid"
s_moe = "Moe"
s_lgbm = "LightGBM"
s_rf = "RandomForest"

names = [s_liquid, s_moe, s_lgbm, s_rf]
experiment = "20250502_161911_all_together"
 Path

def load_test_metrics() -> dict:
    test_metrics = dict()

    for name in names:
        with open()
