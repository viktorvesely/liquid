# %%
import torch

from pathlib import Path
from importlib import reload
import numpy as np
from scipy import interpolate

import delegating_citizen
reload(delegating_citizen)

import LE
reload(LE)

import other.ME
reload(other.ME)

import train
reload(train)

import synth_metrics
reload(synth_metrics)

from matplotlib import pyplot as plt
from matplotlib.colors import ListedColormap


experiment_name = "20250430_081146_moe"
folder = Path(".").resolve() / "experiments" / experiment_name

# le = LE.LE.load(folder)
adapter = other.ME.Moe.load(folder)
model = adapter.model

dataset, _ = train.load_data_synthetic(n_train=10_000, n_valid=100)

# %%
def to_even_plane_values(
    x: np.ndarray,
    y: np.ndarray,
    v: np.ndarray,
    detail: int = 200,
    xlim: tuple[float, float] = (-1, 1),
    ylim: tuple[float, float] = (-1, 1)
    ):

    px = np.linspace(*xlim, detail)
    py = np.linspace(*ylim, detail)

    X, Y = np.meshgrid(px, py)
    interp = interpolate.LinearNDInterpolator(list(zip(x, y)), v)
    Z = interp(X, Y)

    return Z

def to_even_plane_tensors(
    X: torch.Tensor,
    v: torch.Tensor,
    detail: int = 200,
    xlim: tuple[float, float] = (-1, 1),
    ylim: tuple[float, float] = (-1, 1)
):
    return to_even_plane_values(X[:, 0].numpy(), X[:, 1].numpy(), v.numpy(), detail, xlim, ylim)

def plot_Z(Z: np.ndarray, ax: plt.Axes = None, cmap = None, colorbar: bool = False, n_classes: int = -1):

    if cmap is None:
        cmap = ListedColormap(['#1446A0', '#DB3069', '#F5D547'])

    if ax is None:
        fig, ax = plt.subplots(figsize=(6, 6))

    mappable = ax.imshow(Z, extent=[-1, 1, -1, 1], origin='lower', cmap=cmap, interpolation='nearest')
    ax.set_axis_off()

    if colorbar:
        ticks = None if n_classes == -1 else np.arange(n_classes)
        plt.colorbar(mappable, ticks=ticks)

# %%
classifications, Ps = synth_metrics.inference(adapter, dataset)

classifications.shape, Ps.shape
_ = synth_metrics.calc_metrics(adapter, dataset, classifications, Ps, verbal=True)
# Out:
# accuracy 0.749
# power_entropy 0.047
# speaker_entropy 0.125
# region_nmi 0.026

# %%
classifications.shape
# Out:
# torch.Size([1000, 30])

# %%
def plot_citizen_coverage():

    fig, ax = plt.subplots(1, 2, figsize=(10, 5))

    hat = classifications.argmax(1)
    zhat = to_even_plane_tensors(dataset.tensors[0], hat)
    z = to_even_plane_tensors(dataset.tensors[0], dataset.tensors[1])
    plot_Z(z, ax=ax[0])
    plot_Z(zhat, ax=ax[1])
    plt.show()

plot_citizen_coverage()

# %%
def plot_citizen_coverage():

    fig, ax = plt.subplots(1, 2, figsize=(10, 5))

    cmap = ListedColormap(['red', 'blue', 'green', "black"])

    hat = torch.argmax(Ps, 1)
    zhat = to_even_plane_tensors(dataset.tensors[0], hat)
    z = to_even_plane_tensors(dataset.tensors[0], dataset.tensors[1])
    plot_Z(z, ax=ax[0])
    plot_Z(zhat, ax=ax[1], cmap=cmap, colorbar=True, n_classes=4)
    fig.tight_layout()
    plt.show()


plot_citizen_coverage()

# %%
# TODO power entropy plot

from torch.distributions import Categorical
import math
import matplotlib as mpl


def plot_entropy():
    fig, ax = plt.subplots(figsize=(6, 6))

    n = Ps.shape[1]

    dist = Categorical(probs=Ps)
    entropy = dist.entropy() / math.log(n)

    Z = to_even_plane_tensors(dataset.tensors[0], entropy)
    plot_Z(Z, ax=ax, cmap=mpl.colormaps["plasma"], colorbar=True)

    fig.tight_layout()

plot_entropy()

# %%
def plot_citizens_perspective():
    fig, axs = plt.subplots(2, 2, figsize=(6, 6))

    for i_citizen, ax in enumerate(axs.ravel()):
        label_hat = torch.argmax(classifications[i_citizen, :, :], dim=1)
        zhat = to_even_plane_tensors(dataset.tensors[0], label_hat)
        plot_Z(zhat, ax=ax)
        ax.set_title(i_citizen)

    fig.tight_layout()
    plt.show()


plot_citizens_perspective()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[11], line 14
#      10     fig.tight_layout()
#      11     plt.show()
# ---> 14 plot_citizens_perspective()
#
# Cell In[11], line 5, in plot_citizens_perspective()
#       2 fig, axs = plt.subplots(2, 2, figsize=(6, 6))
#       4 for i_citizen, ax in enumerate(axs.ravel()):
# ----> 5     label_hat = torch.argmax(classifications[i_citizen, :, :], dim=1)
#       6     zhat = to_even_plane_tensors(dataset.tensors[0], label_hat)
#       7     plot_Z(zhat, ax=ax)
#
# IndexError: too many indices for tensor of dimension 2

# %%
def plot_citizen_coverage():

    fig, ax = plt.subplots(1, 1, figsize=(10, 5))

    cmap = ListedColormap(['red', 'blue', 'green', "black"])

    hat = torch.argmax(Ps, 1)
    zhat = to_even_plane_tensors(dataset.tensors[0], hat)
    plot_Z(zhat, ax=ax, cmap=cmap, colorbar=True, n_classes=4)
    fig.tight_layout()

    ax.axhline(0, color="white", linestyle="dashed")
    ax.axvline(0, color="white", linestyle="dashed")
    plt.show()

    return fig


fig = plot_citizen_coverage()
fig.savefig("./figures/best_nmi.pdf")
